# %% [markdown]
# # 임베딩

# %%
# %pip install langchain_chroma langchain_openai
# Out:
# Requirement already satisfied: langchain_chroma in .\venv\lib\site-packages (0.2.0)
# Requirement already satisfied: langchain_openai in .\venv\lib\site-packages (0.3.0)
# Requirement already satisfied: chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0 in .\venv\lib\site-packages (from langchain_chroma) (0.5.23)
# Requirement already satisfied: fastapi<1,>=0.95.2 in .\venv\lib\site-packages (from langchain_chroma) (0.115.6)
# Requirement already satisfied: langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 in .\venv\lib\site-packages (from langchain_chroma) (0.3.29)
# Requirement already satisfied: numpy<2.0.0,>=1.26.2 in .\venv\lib\site-packages (from langchain_chroma) (1.26.4)
# Requirement already satisfied: openai<2.0.0,>=1.58.1 in .\venv\lib\site-packages (from langchain_openai) (1.59.7)
# Requirement already satisfied: tiktoken<1,>=0.7 in .\venv\lib\site-packages (from langchain_openai) (0.8.0)
# Requirement already satisfied: build>=1.0.3 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.10.5)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.7.6)
# Requirement already satisfied: uvicorn>=0.18.3 in .\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.34.0)
# Requirement already satisfied: posthog>=2.4.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.8.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.20.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.29.0)
# Requirement already satisfied: tokenizers<=0.20.3,>=0.13.2 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.69.0)
# Requirement already satisfied: bcrypt>=4.0.1 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (4.2.1)
# Requirement already satisfied: typer>=0.9.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.15.1)
# Requirement already satisfied: kubernetes>=28.1.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.10.14)
# Requirement already satisfied: httpx>=0.27.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in .\venv\lib\site-packages (from chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (13.9.4)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in .\venv\lib\site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.41.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in .\venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain_chroma) (1.33)
# Requirement already satisfied: langsmith<0.3,>=0.1.125 in .\venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain_chroma) (0.2.10)
# Requirement already satisfied: packaging<25,>=23.2 in .\venv\lib\site-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain_chroma) (24.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in .\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in .\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in .\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (0.8.2)
# Requirement already satisfied: sniffio in .\venv\lib\site-packages (from openai<2.0.0,>=1.58.1->langchain_openai) (1.3.1)
# Requirement already satisfied: regex>=2022.1.18 in .\venv\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in .\venv\lib\site-packages (from tiktoken<1,>=0.7->langchain_openai) (2.32.3)
# Requirement already satisfied: idna>=2.8 in .\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.58.1->langchain_openai) (3.10)
# Requirement already satisfied: pyproject_hooks in .\venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.2.0)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from build>=1.0.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.4.6)
# Requirement already satisfied: certifi in .\venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in .\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in .\venv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain_chroma) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.37.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.8.0)
# Requirement already satisfied: requests-oauthlib in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.3.0)
# Requirement already satisfied: durationpy>=0.7 in .\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.9)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in .\venv\lib\site-packages (from langsmith<0.3,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.2,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langchain_chroma) (1.0.0)
# Requirement already satisfied: coloredlogs in .\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in .\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (24.12.23)
# Requirement already satisfied: protobuf in .\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (5.29.3)
# Requirement already satisfied: sympy in .\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.13.3)
# Requirement already satisfied: deprecated>=1.2.6 in .\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.2.15)
# Requirement already satisfied: importlib-metadata<=8.5.0,>=6.0 in .\venv\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (8.5.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in .\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.29.0 in .\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-proto==1.29.0 in .\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.29.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.50b0 in .\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.50b0 in .\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.50b0 in .\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.50b0)
# Requirement already satisfied: opentelemetry-util-http==0.50b0 in .\venv\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.50b0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in .\venv\lib\site-packages (from opentelemetry-instrumentation==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.17.2)
# Requirement already satisfied: asgiref~=3.0 in .\venv\lib\site-packages (from opentelemetry-instrumentation-asgi==0.50b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in .\venv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in .\venv\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in .\venv\lib\site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in .\venv\lib\site-packages (from pydantic>=1.9->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in .\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain_openai) (3.4.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in .\venv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in .\venv\lib\site-packages (from rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in .\venv\lib\site-packages (from tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.27.1)
# Requirement already satisfied: click>=8.0.0 in .\venv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in .\venv\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in .\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in .\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.0.1)
# Requirement already satisfied: watchfiles>=0.13 in .\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in .\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (14.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in .\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in .\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in .\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (4.9)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in .\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<=0.20.3,>=0.13.2->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (2024.12.0)
# Requirement already satisfied: zipp>=3.20 in .\venv\lib\site-packages (from importlib-metadata<=8.5.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.21.0)
# Requirement already satisfied: mdurl~=0.1 in .\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.1.2)
# Requirement already satisfied: humanfriendly>=9.1 in .\venv\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyreadline3 in .\venv\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (3.5.4)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in .\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.10,!=0.5.11,!=0.5.12,!=0.5.4,!=0.5.5,!=0.5.7,!=0.5.9,<0.6.0,>=0.4.0->langchain_chroma) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_openai import OpenAIEmbeddings
api_key = "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"

embedding = OpenAIEmbeddings(model='text-embedding-3-large', api_key=api_key)
v = embedding.embed_query("전북대의 장점에 대해 이야기해줘야기해줘")
print(v)
print(len(v))
# Out:
# [0.014356485567986965, -0.04013381525874138, -0.02258700132369995, -0.010489216074347496, 0.03804267570376396, 0.009959728457033634, 0.0076004923321306705, 0.0055763754062354565, -0.0033779966179281473, -0.0006480357842519879, -0.04254667088389397, 0.032385870814323425, 0.04233219474554062, 0.039222292602062225, 0.005415518302470446, 0.0028099704068154097, 0.0011544839944690466, -0.012640678323805332, -0.024396643042564392, -0.010140691883862019, 0.013471771962940693, -0.05134018510580063, 0.004132013767957687, -0.012955689802765846, -0.04096491262316704, -0.004282817244529724, 0.0077479444444179535, 9.760332613950595e-05, -0.004158823285251856, 0.02573711797595024, 0.008404777385294437, 0.028873829171061516, 0.01392753329128027, -0.0326271578669548, -0.038096293807029724, 0.03396763280034065, 0.019959671422839165, -0.03638048842549324, 0.025133904069662094, 0.02717142552137375, -0.007084409706294537, -0.02282828651368618, 0.015777388587594032, 0.00739271892234683, 0.02214464545249939, 0.00638401135802269, -0.0034450204111635685, -0.04187643527984619, -0.016340387985110283, 0.002769756130874157, -0.0023022654931992292, -0.011936928145587444, 0.02568349801003933, -0.028525304049253464, 0.00876670517027378, 0.025040069594979286, 0.009986537508666515, -0.05117933079600334, -0.022788072004914284, -0.00143263244535774, 0.026822902262210846, 0.014115200378000736, 0.003850514069199562, 0.0006333743804134429, 0.0015055207768455148, 0.006316987797617912, 0.012144702486693859, 0.001684809336438775, -0.044718239456415176, 0.011005298234522343, -0.006206398364156485, -0.001034679007716477, 0.0008440802339464426, -0.016742531210184097, 0.003468478797003627, 0.0063773090951144695, 0.03745286911725998, -0.024208975955843925, -0.02416876144707203, 0.016058888286352158, 0.02475856989622116, -0.023230429738759995, -0.035388536751270294, -0.011789476498961449, -0.02368619106709957, 0.013679546304047108, -0.015978461131453514, -0.029168732464313507, 0.0134784746915102, -0.01572377048432827, 0.017225101590156555, -0.03361910954117775, 0.00618964247405529, -0.006303582806140184, -0.00563334533944726, 0.032680775970220566, -0.05549566075205803, -0.0016672156052663922, 0.044155240058898926, 0.01477203331887722, 0.03032154031097889, 0.004034829325973988, -0.020174145698547363, 0.0031802766025066376, 0.02571030706167221, 0.02585775963962078, 0.007553576026111841, 0.02140738256275654, -0.009463752619922161, -0.02761378139257431, -0.011742559261620045, -8.59788924572058e-05, -0.03742605820298195, 0.012017357163131237, -0.038686104118824005, -0.013022713363170624, -0.010375275276601315, -0.010294847190380096, -0.01589803211390972, 0.005643398966640234, 0.029973017051815987, 0.019423481076955795, 0.016447626054286957, -0.05257342383265495, -0.029329590499401093, -0.01753341034054756, -0.022962333634495735, 0.04123300686478615, 0.02461111918091774, -0.0019017986487597227, 0.015469079837203026, 0.06337764859199524, 0.01789533905684948, 0.009323002770543098, 0.002977529773488641, 0.0048793284222483635, 0.06600498408079147, 0.0573723241686821, -0.04831071197986603, -0.016608484089374542, 0.012077677994966507, -0.012211726047098637, -0.0033846991136670113, 0.001286855898797512, 0.022091025486588478, -0.009725145064294338, 0.06868593394756317, 0.020763956010341644, -0.013250594027340412, 0.018029386177659035, 0.01569696143269539, -0.04351181536912918, -0.005046887788921595, 0.007272075861692429, 0.0497584268450737, -0.02006690762937069, 0.0008704708307050169, 0.05412837490439415, -0.013176867738366127, 0.024946236982941628, -0.01584441214799881, -0.000454085849924013, -0.002556955674663186, 0.028364447876811028, 0.00875330064445734, 0.011782773770391941, -0.03659496456384659, -0.03581748902797699, -0.018083006143569946, 0.019329646602272987, -0.02140738256275654, -0.02820359170436859, -0.02134035900235176, -0.022037407383322716, -0.004011371172964573, 0.015080342069268227, -0.010898060165345669, -0.015884626656770706, -0.004121960140764713, -0.0494099035859108,  ...
# 3072

# %% [markdown]
# ## PDF 읽기

# %%
# %pip install pypdf
# Out:
# Collecting pypdf
#   Using cached pypdf-5.1.0-py3-none-any.whl.metadata (7.2 kB)
# Using cached pypdf-5.1.0-py3-none-any.whl (297 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import PyPDFLoader

# PDF 파일을 읽어서 텍스트 데이터를 추출합니다.
loader = PyPDFLoader('./data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf' )
jjb = loader.load()
print(jjb)
# Out:
# [Document(metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 0}, page_content='10▶\n인공지능 기법을 활용한 농촌지역의 \n객체 정보 추출방안\n1. 머리말\n최근 4차 산업혁명 기술이 경제 화두로 부상한 이후 3D, 빅데이터, IoT, \nAI를 활용한 사업들이 성장세를 띄고 있으며, 특히 AI 기술은 스마트도시, \n스마트건설, 보건복지, 안전 등 다양한 분야로 활용되고 있다. 이러한 4차 \n산업혁명 기술은 농업 및 농촌분야에서도 빠르게 적용되고 있다. 농촌분야\n에서는 ICT, 공간빅데이터 등을 활용해 증거기반 주민체감형 지역개발과 \n같은 지능형 스마트 농촌을 구현하기 위한 연구가 수행되고 있으며, 농업\n분야에서는 빅데이터, AI, 사물인터넷 등 ICT 기술을 접목한 스마트팜 연\n구가 수행되고 있다. 이처럼 농업과 농촌 분야에 신기술의 도입으로 학문\n분야의 확장과 새로운 비즈니스를 창출하고 있다. \n이러한 변화속에서 정부는 농촌공간의 쾌적성과 편리성을 높이고, 농촌\n주민 삶의 질 향상을 위해 농산촌 지원강화 및 성장환경 조성이라는 국정\n목표를 세우고, 이에 대한 세부실천 목표를 제시하였다. 이 가운데 하나가 \n농촌공간 재구조화 계획이다. 이 계획은 농촌공간의 여건에 따라 주거·\n생산·서비스 등 기능적으로 구분되고 재배치될 수 있도록 장기계획 수립 \n및 농촌특화지구 도입을 목표로 하고 있다. 이를 위해 「농촌공간 재구조화 \n및 재생지원을 위한 법률」(농촌공간재구조화법)을 22년도에 제정하였으며, \n24년부터 시행에 들어가게 된다. 또한 장기적인 계획에 대응하여 서비스 \n거점 확충, 주거지 인접 공장·축사 정비·집적화 등을 지원하는 농촌재생 \n프로젝트를 추진하고자 하고 있다. \n농촌지역을 대상으로 국정목표에 따른 세부실천과제를 수행하기 위해서\n는 기존의 현황에 대한 파악이 우선되어야 한다. 현재 우리나라의 농촌지\n역에 해당하는 공간은 국토기본법, 국토의 계획 및 이용에 관한 법률(국토\n02\n전 정 배\n공간정보연구원 \n/ 선임연구원\njbjeon@lx.or.kr\n석 승 원\n전북대학교 스마트팜학과 \n/ 학사과정\nchamp9162@jbnu.ac.kr\n김 솔 희\n전북대학교 스마트팜학과 \n/ 연구교수\nsolhee1101@jbnu.ac.kr\n김 태 곤\n전북대학교 스마트팜학과 \n/ 교수\ntaegon@jbnu.ac.kr\nRural Resources\n+\n특집    인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안'), Document(metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 1}, page_content='11▶▶Vol. 66 No. 2, May 2024\n계획법), 공간정보 구축 및 관리 등에 관한 법률\n(공간정보관리법)에 영향을 받는다. 국토기본법\n에 따른 국토종합계획, 국토계획법에 따른 도시·\n군 관리계획과 함계 용도지역·지구 등과 같은 관\n리를 받고 있으며, 공간정보관리법에 따라 법정지\n목에 영향을 받는다. 따라서 현재 시행되고 있는 \n법률을 기준으로 농촌공간의 현황에 대해서 파악\n해야 한다. 이를 위해서는 다양한 법률에 따라 관\n리되고 있는 많은 공간데이터를 융복합하여야 한\n다. 또한 농촌공간의 정확한 현황을 파악하기 위\n한 기법도 필요하다. 현재 우리나라 토지(농경지)\n는 토지·농지대장과 같은 공적장부를 통해 관리\n되고 있다. 공적장부는 토지에 대한 관리를 위해 \n비치되는 장부이지만, 실제 현황에 대한 직접적인 \n조사에 많은 비용과 시간이 필요하기 때문에 정보 \n갱신의 주기가 빠르지 않다는 단점이 있다. 이로 \n인해 공적장부에 등록된 정보와 현실의 현황이 다\n르게 나타나고 있으며, 이로 인해 다양한 문제점\n이 야기되고 있는 실정이다. 따라서 이러한 단점\n의 보완이 필요하며, 인공지능 기법이 새로운 대\n안으로 부상하고 있다. \n이처럼 농촌지역의 미래지향적인 발전과 농업\n활동의 안정적인 지속성을 위해서는 농촌 맞춤형\n의 공간재구조화 필요하며, 이를 위해서 정확한 \n정보를 기반으로 현재의 상황을 진단하여야 한다. \n따라서 최근 부상하고 있는 인공지능 기법을 활용\n하여, 농촌공간의 실제 현황 정보를 파악하고, 이\n를 타 법률에 따른 근거와 비교하여 객관적인 현\n상황을 파악할 수 있는 프로토타입의 분석방법을 \n제안하고자 한다. \n2. 인공지능 기법을 이용한 객관적 객체 탐지 \n최근 인공지능을 활용한 이미지 인식기법\n이 빠르게 고도화되고 있다. 이미지 인식 기\n술은 2012년 대규모 이미지 인식 경진대회인 \nILSVRC(ImageNet Large Scale Visual Rec-\nognition Challenge)에서 토론토 대학 연구진이 \nCNN(Convolution Neural \nNetwork) 기반의 딥\n러닝(Deep learning) 알고리즘으로 기존의 방법\n론에 대비해 압도적인 성능으로 우승하며 전세계\n적으로 주목을 받기 시작하였다. 이후 인공지능 \n기법을 통한 이미지 인식 기술은 빠른 속도로 발\n전하고 있다. 2015년에는 Joseph Redmon에 의\nSources: Zou, Z., Shi, Z., Guo, Y., & Ye, J. (2019). Object detection in 20 years\nFig. 1. Object detection in 20 year'), Document(metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 2}, page_content='12▶\n해서 YOLO(You Only Look ONCE) 알고리즘이 \n최초로 공개되었다. 이 알고리즘은 기존의 방법론 \n대비 이미지 처리 시간을 대폭 감소시킬 수 있는 \n방법으로 모델이 구성되었으며, 실시간 영상의 객\n체인지가 가능해 많은 분야에 활용 가능성을 보여\n주었다. 이로 인하여 수많은 연구자가 YOLO 모\n델을 채용하고 다양한 분야에서 활용되고 있다. \nYOLO 알고리즘은 이미지를 그리드로 나누고, \n각 그리드 셀이 객체의 중심을 포함할 확률과 해\n당 객체에 대한 바운딩 박스(객체를 둘러싼 사각\n형 박스)의 좌표, 그리고 그 객체의 클래스를 예\n측한다. 여기서 객체탐지의 성능은 정밀도(pre-\ncision), 재현율(recall), 평균정밀도(AP,  Aver-\nage Precision)로 평가하게 된다(김준석과 홍일\n영, 2021). \n정밀도는 기존에 설정된 정답과 모델\n을 통해 탐지된 결과물이 일치하는 비율을 의미하\n며, 다음의 식 (1)과 같이 계산된다.\n- 3 -\nSources: Zou, Z., Shi, Z., Guo, Y., & Ye, J. (2019). Object detection in 20 years\nFig. 1  O bject d etection i n 2 0 y ears\n YOLO 알고리 즘은 OLO 모델은 이미지 를 그리 드로 나누고, 각 그리 드 셀이 객 체 의  중심을  \n포함할 확률과 해당 객 체 에 대한  바운딩 박스(객 체 를 둘러싼 사각형 박스)의  좌표, 그리 고 \n그 객 체 의  클래스를 예측한 다. 여기 서 객 체 탐 지 의  성능 은 정 밀도(precision), 재현율(recall), \n평균정 밀도(AP,  Average Precision)로 평가하게 된다(김준석과 홍일영, 2021). 정 밀도는 기\n존에 설정 된 정 답과 모델을  통해 탐 지 된 결과물이 일치하는 비율을  의 미한 다(eq.1).\n\ue0f4\ue0f6\ue0e9\ue0ed\ue0f7\ue0ed\ue0f3\ue0f2 \ue047 \ue06d\ue013\ue0f6\ue0f9\ue0e9 \ue00f\ue0f3\ue0f7\ue0ed\ue0f8\ue0ed\ue0fa\ue0e9 \ue048\ue005\ue0e5\ue0f0\ue0f7\ue0e9 \ue00f\ue0f3\ue0f7\ue0ed\ue0f8\ue0ed ...

# %% [markdown]
# ## 청크로 나누기

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# 텍스트 데이터를 1000자 단위로 나눕니다. overlap은 100자로 설정합니다.
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
all_splits = text_splitter.split_documents(jjb)

for i, split in enumerate(all_splits):
    print(f"Split {i+1}:------------------------------------\n")
    print(split)

    if i > 5:
        break
# Out:
# Split 1:------------------------------------
#
# page_content='10▶
# 인공지능 기법을 활용한 농촌지역의
# 객체 정보 추출방안
# 1. 머리말
# 최근 4차 산업혁명 기술이 경제 화두로 부상한 이후 3D, 빅데이터, IoT,
# AI를 활용한 사업들이 성장세를 띄고 있으며, 특히 AI 기술은 스마트도시,
# 스마트건설, 보건복지, 안전 등 다양한 분야로 활용되고 있다. 이러한 4차
# 산업혁명 기술은 농업 및 농촌분야에서도 빠르게 적용되고 있다. 농촌분야
# 에서는 ICT, 공간빅데이터 등을 활용해 증거기반 주민체감형 지역개발과
# 같은 지능형 스마트 농촌을 구현하기 위한 연구가 수행되고 있으며, 농업
# 분야에서는 빅데이터, AI, 사물인터넷 등 ICT 기술을 접목한 스마트팜 연
# 구가 수행되고 있다. 이처럼 농업과 농촌 분야에 신기술의 도입으로 학문
# 분야의 확장과 새로운 비즈니스를 창출하고 있다.
# 이러한 변화속에서 정부는 농촌공간의 쾌적성과 편리성을 높이고, 농촌
# 주민 삶의 질 향상을 위해 농산촌 지원강화 및 성장환경 조성이라는 국정
# 목표를 세우고, 이에 대한 세부실천 목표를 제시하였다. 이 가운데 하나가
# 농촌공간 재구조화 계획이다. 이 계획은 농촌공간의 여건에 따라 주거·
# 생산·서비스 등 기능적으로 구분되고 재배치될 수 있도록 장기계획 수립
# 및 농촌특화지구 도입을 목표로 하고 있다. 이를 위해 「농촌공간 재구조화
# 및 재생지원을 위한 법률」(농촌공간재구조화법)을 22년도에 제정하였으며,
# 24년부터 시행에 들어가게 된다. 또한 장기적인 계획에 대응하여 서비스
# 거점 확충, 주거지 인접 공장·축사 정비·집적화 등을 지원하는 농촌재생
# 프로젝트를 추진하고자 하고 있다.
# 농촌지역을 대상으로 국정목표에 따른 세부실천과제를 수행하기 위해서
# 는 기존의 현황에 대한 파악이 우선되어야 한다. 현재 우리나라의 농촌지
# 역에 해당하는 공간은 국토기본법, 국토의 계획 및 이용에 관한 법률(국토
# 02
# 전 정 배
# 공간정보연구원
# / 선임연구원
# jbjeon@lx.or.kr
# 석 승 원
# 전북대학교 스마트팜학과
# / 학사과정
# champ9162@jbnu.ac.kr' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 0}
# Split 2:------------------------------------
#
# page_content='02
# 전 정 배
# 공간정보연구원
# / 선임연구원
# jbjeon@lx.or.kr
# 석 승 원
# 전북대학교 스마트팜학과
# / 학사과정
# champ9162@jbnu.ac.kr
# 김 솔 희
# 전북대학교 스마트팜학과
# / 연구교수
# solhee1101@jbnu.ac.kr
# 김 태 곤
# 전북대학교 스마트팜학과
# / 교수
# taegon@jbnu.ac.kr
# Rural Resources
# +
# 특집    인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 0}
# Split 3:------------------------------------
#
# page_content='11▶▶Vol. 66 No. 2, May 2024
# 계획법), 공간정보 구축 및 관리 등에 관한 법률
# (공간정보관리법)에 영향을 받는다. 국토기본법
# 에 따른 국토종합계획, 국토계획법에 따른 도시·
# 군 관리계획과 함계 용도지역·지구 등과 같은 관
# 리를 받고 있으며, 공간정보관리법에 따라 법정지
# 목에 영향을 받는다. 따라서 현재 시행되고 있는
# 법률을 기준으로 농촌공간의 현황에 대해서 파악
# 해야 한다. 이를 위해서는 다양한 법률에 따라 관
# 리되고 있는 많은 공간데이터를 융복합하여야 한
# 다. 또한 농촌공간의 정확한 현황을 파악하기 위
# 한 기법도 필요하다. 현재 우리나라 토지(농경지)
# 는 토지·농지대장과 같은 공적장부를 통해 관리
# 되고 있다. 공적장부는 토지에 대한 관리를 위해
# 비치되는 장부이지만, 실제 현황에 대한 직접적인
# 조사에 많은 비용과 시간이 필요하기 때문에 정보
# 갱신의 주기가 빠르지 않다는 단점이 있다. 이로
# 인해 공적장부에 등록된 정보와 현실의 현황이 다
# 르게 나타나고 있으며, 이로 인해 다양한 문제점
# 이 야기되고 있는 실정이다. 따라서 이러한 단점
# 의 보완이 필요하며, 인공지능 기법이 새로운 대
# 안으로 부상하고 있다.
# 이처럼 농촌지역의 미래지향적인 발전과 농업
# 활동의 안정적인 지속성을 위해서는 농촌 맞춤형
# 의 공간재구조화 필요하며, 이를 위해서 정확한
# 정보를 기반으로 현재의 상황을 진단하여야 한다.
# 따라서 최근 부상하고 있는 인공지능 기법을 활용
# 하여, 농촌공간의 실제 현황 정보를 파악하고, 이
# 를 타 법률에 따른 근거와 비교하여 객관적인 현
# 상황을 파악할 수 있는 프로토타입의 분석방법을
# 제안하고자 한다.
# 2. 인공지능 기법을 이용한 객관적 객체 탐지
# 최근 인공지능을 활용한 이미지 인식기법
# 이 빠르게 고도화되고 있다. 이미지 인식 기
# 술은 2012년 대규모 이미지 인식 경진대회인
# ILSVRC(ImageNet Large Scale Visual Rec-
# ognition Challenge)에서 토론토 대학 연구진이' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 1}
# Split 4:------------------------------------
#
# page_content='ILSVRC(ImageNet Large Scale Visual Rec-
# ognition Challenge)에서 토론토 대학 연구진이
# CNN(Convolution Neural
# Network) 기반의 딥
# 러닝(Deep learning) 알고리즘으로 기존의 방법
# 론에 대비해 압도적인 성능으로 우승하며 전세계
# 적으로 주목을 받기 시작하였다. 이후 인공지능
# 기법을 통한 이미지 인식 기술은 빠른 속도로 발
# 전하고 있다. 2015년에는 Joseph Redmon에 의
# Sources: Zou, Z., Shi, Z., Guo, Y., & Ye, J. (2019). Object detection in 20 years
# Fig. 1. Object detection in 20 year' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 1}
# Split 5:------------------------------------
#
# page_content='12▶
# 해서 YOLO(You Only Look ONCE) 알고리즘이
# 최초로 공개되었다. 이 알고리즘은 기존의 방법론
# 대비 이미지 처리 시간을 대폭 감소시킬 수 있는
# 방법으로 모델이 구성되었으며, 실시간 영상의 객
# 체인지가 가능해 많은 분야에 활용 가능성을 보여
# 주었다. 이로 인하여 수많은 연구자가 YOLO 모
# 델을 채용하고 다양한 분야에서 활용되고 있다.
# YOLO 알고리즘은 이미지를 그리드로 나누고,
# 각 그리드 셀이 객체의 중심을 포함할 확률과 해
# 당 객체에 대한 바운딩 박스(객체를 둘러싼 사각
# 형 박스)의 좌표, 그리고 그 객체의 클래스를 예
# 측한다. 여기서 객체탐지의 성능은 정밀도(pre-
# cision), 재현율(recall), 평균정밀도(AP,  Aver-
# age Precision)로 평가하게 된다(김준석과 홍일
# 영, 2021).
# 정밀도는 기존에 설정된 정답과 모델
# 을 통해 탐지된 결과물이 일치하는 비율을 의미하
# 며, 다음의 식 (1)과 같이 계산된다.
# - 3 -
# Sources: Zou, Z., Shi, Z., Guo, Y., & Ye, J. (2019). Object detection in 20 years
# Fig. 1  O bject d etection i n 2 0 y ears
#  YOLO 알고리 즘은 OLO 모델은 이미지 를 그리 드로 나누고, 각 그리 드 셀이 객 체 의  중심을
# 포함할 확률과 해당 객 체 에 대한  바운딩 박스(객 체 를 둘러싼 사각형 박스)의  좌표, 그리 고
# 그 객 체 의  클래스를 예측한 다. 여기 서 객 체 탐 지 의  성능 은 정 밀도(precision), 재현율(recall),
# 평균정 밀도(AP,  Average Precision)로 평가하게 된다(김준석과 홍일영, 2021). 정 밀도는 기
# 존에 설정 된 정 답과 모델을  통해 탐 지 된 결과물이 일치하는 비율을  의 미한 다(eq.1).
#      
#   (1)' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 2}
# Split 6:------------------------------------
#
# page_content='     
#   (1)
#  여기 서, true positive와 false positi ve를 결정 하는 기 준은 IOU(Intersection Over Union)를
# 기 준으로 설정 한 다. IOU는 정 답으로 설정 된 경계박스와 모델을  통해 예측된 결과박스와 중
# 첩되는 부분의  면적을  합집합 면적의  비로 계산된다. 이렇게 산정 된 IOU 값을  통하여 정 답
# 지 와 일치하는지 , 일치하지  않은지 를 설정 하게 된다. 본 연구에서는 IOU 값이 0.5 이상으로
# 탐 지 된 객 체 를 일치하는 것으로 적용 하였다(Fig. 00).
# Fig. 2  I OU o rganization s cheme f or d etermining o bject r ecognition
# 다음으로 재현율은 실제 참값(True)인  것 중에서 모델이 True라고 예측한  비율을  말 하며,
#  (1)
# 여기서, true
# positive와 false positive를 결정
# 하는 기준은 IOU(Intersection Over Union)를
# 기준으로 설정한다. IOU는 정답으로 설정된 경계
# 박스와 모델을 통해 예측된 결과박스와 중첩되는
# 부분의 면적을 합집합 면적의 비로 계산된다. 이
# 렇게 산정된 IOU 값을 통하여 정답지와 일치하는
# 지, 일치하지 않은지를 설정하게 된다. 본 연구에
# 서는 IOU 값이 0.5 이상으로 탐지된 객체를 일치
# 하는 것으로 적용하였다(Fig. 2).
# 다음으로 재현율은 실제 참값(True)인 것 중에
# 서 모델이 True라고 예측한 비율을 말하며, 다음
# 의 식 (2)와 같이 산정된다.
#
# - 4 -
# 다음의  식 2와 같이 산정 된다.
#      
#   (2)
# 마지 막으로 평균정 밀도는 예측된 모델의  정 밀도-재현율곡선(Precision-Recall Curve, PRC)' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 2}
# Split 7:------------------------------------
#
# page_content='  (2)
# 마지 막으로 평균정 밀도는 예측된 모델의  정 밀도-재현율곡선(Precision-Recall Curve, PRC)
# 의  아래영역  면적으로 산출 된다. 이는 재현율이 증가함에 따라 정 밀도가 얼마나 유지 되는지
# 를 측정 하는 지 표로 모델을  성능 을  평가하는 대표적인  항목이다. 여기 에 여러개의  객 체 를
# 동시에 탐 지 하는 경우 mAP(Mean Average Precision)을  산정 하여 모델을  평가한 다.
# 3 .  인 공지능 기 법을 통 한 농 촌지역의 객 체 탐 지 실 증
# YOLO 알고리 즘 기 반으로 드론으로 촬영된 영상을  활 용 하여 객 체  탐 지 를 실증하였다. 객 체
# 탐 지 는 건축물에 해당하는 주택과 비닐하우스로 한 정 하였다. 분석을  위한  건축물 데이터는
# 약 16만개를 이용 하였으며, 비닐하우스는 약 12만개를 이용 하였다(Table 1).
#   구축된 데이터의  80%는 학습을  수행하고, 20%에 대해서 검증을  실시하였으며, 학습 결과
# 를 평가하기 위해서 클래스별로 3가지의 평가지표를 살펴보았다. 옥상형 건축물과 비닐하우
# 스에서는 정확도와 재현율이 0.8 이상으로 나타났으며, IOU를 50% 이상으로 설정한 평균
# 정밀도에서도 0.8이상으로 나타나 높은 비율로 객체를 인식하는 것으로 나타났다(Table 2).
# Division Precision Recall AP50 AP50-95 mAP50 mAP50-95
# Class 1 RT 0.851 0.858 0.898 0.665
# 0.808 0.610Class 2 RO 0.780 0.750 0.790 0.606
# Class 3 BH 0.924 0.898 0.932 0.783
# Class 4 WH 0.884 0.901 0.920 0.685
# Table 2  T est r esults u sing t he Y OLO a lgorithm
#  학습된 YOLO 모델을  QGIS를 이용 하여 드론영상에 적용 하였다(Fig 3). 그 결과 건축물(지' metadata={'source': './data/인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf', 'page': 2}

# %%
from glob import glob
from tqdm import tqdm

all_splits = []

# PDF 파일을 읽어서 텍스트 데이터를 추출합니다.
for g in tqdm(glob("C:/github/llm_2025_01/data/*.pdf")):
    loader = PyPDFLoader(g)
    pdf_txt = loader.load()

    # 텍스트 데이터를 1000자 단위로 나눕니다. overlap은 100자로 설정합니다.
    text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
    all_splits += text_splitter.split_documents(pdf_txt)

print(len(all_splits))
# Out:
# 100%|██████████| 9/9 [00:03<00:00,  2.86it/s]
# 307

# %% [markdown]
# ## Vector DB 생성
#
# - 이미 있다면, 읽기
# - 없다면 임베딩해서 생성하기

# %%
from langchain_chroma import Chroma
import os

persist_directory = './chroma_store'

# 만약 이미 저장된 크로마DB 가 없다면 새로 만듭니다.
if not os.path.exists(persist_directory):
    print("Creating new Chroma store")
    vectorstore = Chroma.from_documents(
        documents=all_splits,
        embedding=embedding,
        persist_directory=persist_directory
    )
else:
    print("Loading existing Chroma store")
    vectorstore = Chroma(
        persist_directory=persist_directory, 
        embedding_function=embedding
    )
# Out:
# Creating new Chroma store

# %%
retriever = vectorstore.as_retriever(k=3)
docs = retriever.invoke("인공지능이 농업분야에 사용될 수 있나?")

for d in docs:
    print(d)
    print('------')
# Out:
# page_content='54▶
# 인공지능을 활용한 농업기반시설물
# 안전점검 방안
# 1. 머리말
# 농업기반시설물은 농업 생산과 농촌 지역의 안정적인 생활을 지원하는
# 핵심 인프라이다. 농업기반시설물은 관개 시스템, 저수지 및 수로 등 다양
# 한 형태로 존재하며, 그 기능적 중요성으로 인해 지속적인 유지보수와 안
# 전 점검이 필수적이다. 그러나 전통적인 점검 방식은 주로 시각적 검사와
# 물리적 테스트에 의존하고 있다. 이러한 방식은 종종 휴먼 에러(human
# error)를 동반하며, 예상치 못한 구조적 결함이나 안전 문제를 제때 발견
# 하지 못할 위험이 있다. 특히, 접근이 어려운 장소나 고위험 시설에서는 이
# 러한 점검 방식의 한계가 있다.
# 최근 몇 년간 인공지능(AI) 기술의 급격한 발전은 다양한 산업 분야에 혁
# 신적인 변화를 가져오고 있으며, 농업기반시설물의 안전 점검 분야도 예외
# 가 아니다. AI와 컴퓨터 비전 기술을 활용한 자동화된 점검 시스템은 고해
# 상도 영상자료를 통해 구조물의 상태를 실시간으로 분석하고 평가할 수 있
# 다. 이러한 접근 방식은 전통적인 방법에 비해 효율성과 정확성을 크게 향
# 상시키며, 점검 주기를 단축하고 비용을 절감할 수 있다.
# 특히, CCTV 장비, 드론 등을 활용한 영상 수집은 접근이 어려운 구조물
# 이나 넓은 지역을 빠르고 안전하게 점검 할 수 있는 방법을 제공한다. 고해
# 상도 카메라와 다양한 센서는 구조물의 표면 상태, 균열, 부식 등을 상세히
# 촬영할 수 있으며, 수집된 데이터는 AI 모델을 통해 자동으로 분석된다. 딥
# 러닝(Deep Learning) 알고리즘은 이러한 영상 데이터를 기반으로 구조물
# 의 결함을 식별하고, 그 심각성을 평가하며, 유지보수의 필요성을 예측할
# 수 있다.
# AI 기반 점검 시스템은 크게 두 가지 주요 단계로 나눌 수 있다. 첫 번째
# Rural Resources
# +
# 학술기술기사    인공지능을 활용한 농업기반시설물 안전점검 방안
# 03
# 허 준
# 한국농어촌공사 농어촌연구원
# / 책임연구원
# jheo01@ekr.or.kr
# 허 건' metadata={'page': 0, 'source': 'C:/github/llm_2025_01/data\\인공지능을 활용한 농업기반시설물 안전점검 방안.pdf'}
# ------
# page_content='10▶
# 인공지능 기법을 활용한 농촌지역의
# 객체 정보 추출방안
# 1. 머리말
# 최근 4차 산업혁명 기술이 경제 화두로 부상한 이후 3D, 빅데이터, IoT,
# AI를 활용한 사업들이 성장세를 띄고 있으며, 특히 AI 기술은 스마트도시,
# 스마트건설, 보건복지, 안전 등 다양한 분야로 활용되고 있다. 이러한 4차
# 산업혁명 기술은 농업 및 농촌분야에서도 빠르게 적용되고 있다. 농촌분야
# 에서는 ICT, 공간빅데이터 등을 활용해 증거기반 주민체감형 지역개발과
# 같은 지능형 스마트 농촌을 구현하기 위한 연구가 수행되고 있으며, 농업
# 분야에서는 빅데이터, AI, 사물인터넷 등 ICT 기술을 접목한 스마트팜 연
# 구가 수행되고 있다. 이처럼 농업과 농촌 분야에 신기술의 도입으로 학문
# 분야의 확장과 새로운 비즈니스를 창출하고 있다.
# 이러한 변화속에서 정부는 농촌공간의 쾌적성과 편리성을 높이고, 농촌
# 주민 삶의 질 향상을 위해 농산촌 지원강화 및 성장환경 조성이라는 국정
# 목표를 세우고, 이에 대한 세부실천 목표를 제시하였다. 이 가운데 하나가
# 농촌공간 재구조화 계획이다. 이 계획은 농촌공간의 여건에 따라 주거·
# 생산·서비스 등 기능적으로 구분되고 재배치될 수 있도록 장기계획 수립
# 및 농촌특화지구 도입을 목표로 하고 있다. 이를 위해 「농촌공간 재구조화
# 및 재생지원을 위한 법률」(농촌공간재구조화법)을 22년도에 제정하였으며,
# 24년부터 시행에 들어가게 된다. 또한 장기적인 계획에 대응하여 서비스
# 거점 확충, 주거지 인접 공장·축사 정비·집적화 등을 지원하는 농촌재생
# 프로젝트를 추진하고자 하고 있다.
# 농촌지역을 대상으로 국정목표에 따른 세부실천과제를 수행하기 위해서
# 는 기존의 현황에 대한 파악이 우선되어야 한다. 현재 우리나라의 농촌지
# 역에 해당하는 공간은 국토기본법, 국토의 계획 및 이용에 관한 법률(국토
# 02
# 전 정 배
# 공간정보연구원
# / 선임연구원
# jbjeon@lx.or.kr
# 석 승 원
# 전북대학교 스마트팜학과
# / 학사과정
# champ9162@jbnu.ac.kr' metadata={'page': 0, 'source': 'C:/github/llm_2025_01/data\\인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안.pdf'}
# ------
# page_content='업데이트 소식으로 가득하다. 우리 기관에서도 생
# 성형 AI가 스마트농업에 게임체인저가 될 수 있을
# 지 기대가 크다. 생성형 AI 유료 결제를 요청하는
# 모든 직원에게 비용을 지불하고 윤리교육 및 활
# 용 교육 등 각종 교육프로그램을 개설하고 있으며
# AI 활용 경진대회를 여는 등 농업 분야 발전을 위
# 그림 1. 팜두레(farmdure) UI' metadata={'page': 1, 'source': 'C:/github/llm_2025_01/data\\생성형 AI 기반의 영농 의사결정 지원 시스템 개발과 향후계획.pdf'}
# ------
# page_content='3▶▶Vol. 66 No. 2, May 2024
# 이다. 그래서 기후와 작물 생육을 연계하여 실시
# 간으로 시각화하고1 작물 생육을 기준으로 APEX
# 모델 농작업 입력파일( *.OPC)을 생성하는 프로
# 그램 개발에 착수했다.
# 프로토타입 프로그램을 만들어보니 이 프로그
# 램은 모델을 돌리는 데 보다 농업인이 영농 의사
# 결정을 지원하는 데 사용하는 것이 더 유용하리라
# 판단했다. 또한, OPC 파일을 만들게 아니라 영
# 농일지를 만드는 것이 더 실용적일 것이다. 그래
# 서 아이디어 특허를 출원(최순군 등, 2021), ㈜노
# 트스퀘어 이준혁 대표와 함께 개발에 착수했다.
# 프로그램 이름은 일단 농업인을 돕는다는 의미로
# ‘팜두레(farmdure)’로 하였다(그림 1).
# 이준혁 대표는 팜두레가 단순 영농 스케줄러가
# 아니라 영농 의사결정 지원 시스템이 되기 위해
# 선 전문가 수준의 농업정보 제공이 필요하다고 생
# 각했다. 그래서 서로의 영농계획서를 공유하고 토
# 1)   FAO AquaCrop 모델(Steduto et al., 2009)은 작물 매개변수
# 를
# 수정할 때마다 실시간으로 작물 생육과 생장에 관한 정보를
# 시각화하여 제공한다. 이 GUI를 벤치마킹 하려고 하였다.
# 론하며 전문가 자문을 받는 등 소셜미디어 기능을
# 구현하고자 했다. 좋은 생각이었다. 활성화 여부
# 를 떠나 농업에 관해 정보를 공유하는 네이버 밴
# 드도 많이 있고 우리 국립농업과학원에는 ‘유기농
# 업연구회’가 운영되고 있기도 하다. 그런데 “자문
# 해 줄 전문가는 누구예요?”라는 질문에 이준혁 대
# 표가 답했다. “최 박사님께서….”
# “제가요?”
# 3. ChatGPT의 등장
# 요새 생성형 AI가 연일 화제다. 유튜브에서
# 는 하루가 멀다고 새로운 대규모언어모델(LLM,
# Large Language Model)에 관한 이야기, 신규
# 업데이트 소식으로 가득하다. 우리 기관에서도 생
# 성형 AI가 스마트농업에 게임체인저가 될 수 있을
# 지 기대가 크다. 생성형 AI 유료 결제를 요청하는' metadata={'page': 1, 'source': 'C:/github/llm_2025_01/data\\생성형 AI 기반의 영농 의사결정 지원 시스템 개발과 향후계획.pdf'}
# ------

# %% [markdown]
# ## 답변 생성

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder # 1
from langchain.chains.combine_documents import create_stuff_documents_chain # 2
from langchain_openai import ChatOpenAI # 3

chat = ChatOpenAI(model="gpt-4o", api_key=api_key) # 3

# 4
question_answering_prompt = ChatPromptTemplate.from_messages(
    [
        ( # 4-1
            "system",
            "사용자의 질문에 대해 아래 context에 기반하여 답변하라. 답변할 때는 metadata를 활용해 pdf 파일 이름과 페이지 번호를 같이 밝혀라. :\n\n{context}",
        ),
        MessagesPlaceholder(variable_name="messages"), # 4-2
    ]
)

document_chain = create_stuff_documents_chain(chat, question_answering_prompt) # 5

# %%
from langchain.memory import ChatMessageHistory

# 1. 채팅 메시지를 저장할 메모리 객체를 생성합니다.
chat_history = ChatMessageHistory() 
# 2. 사용자의 질문을 메모리에 저장합니다.
chat_history.add_user_message("인공지능이 농업분야에서 어떻게 사용될 수 있을까?") 

# 3. 문서를 검색하고, 사용자의 질문에 대한 답변을 생성합니다.
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 4. 생성된 답변을 메모리에 저장합니다.
chat_history.add_ai_message(answer) 

print(answer)
# Out:
# 인공지능은 농업 분야에서 다양한 방식으로 활용될 수 있습니다. 첫 번째로, AI와 컴퓨터 비전 기술을 활용하여 농업기반시설물의 안전 점검을 자동화할 수 있습니다. 이는 고해상도 영상 자료를 통해 구조물의 상태를 실시간으로 분석하고 평가할 수 있게 해주며, 전통적인 점검 방법에 비해 효율성과 정확성을 크게 향상시킵니다. 예를 들어, CCTV 장비와 드론을 활용하여 접근이 어려운 구조물이나 넓은 지역을 빠르고 안전하게 점검할 수 있으며, 고해상도 카메라와 다양한 센서로 구조물의 표면 상태, 균열, 부식 등을 상세히 촬영할 수 있습니다. 이러한 데이터는 AI 모델을 통해 자동으로 분석되어 구조물의 결함을 식별하고, 그 심각성을 평가하며, 유지보수의 필요성을 예측할 수 있습니다 (Source: "인공지능을 활용한 농업기반시설물 안전점검 방안", Rural Resources, p.03).
#
# 두 번째로, 농촌 지역의 객체 정보 추출에 인공지능 기법이 활용될 수 있습니다. AI는 공간빅데이터, IoT와 결합하여 농촌지역의 현황 파악, 주민체감형 지역개발 등을 위한 증거 기반의 다양한 지능형 서비스를 구현할 수 있습니다. 이러한 기술들은 농촌의 쾌적성과 편리성을 높이고, 삶의 질 향상과 성장환경 조성을 위한 국정 목표와 밀접히 연관되어 사용됩니다 (Source: "인공지능 기법을 활용한 농촌지역의 객체 정보 추출방안", Rural Resources, p.02).

# %%
query = "홍수가 걱정된다."
chat_history.add_user_message(query) 
docs = retriever.invoke(query)

# 3. 문서를 검색하고, 사용자의 질문에 대한 답변을 생성합니다.
answer = document_chain.invoke(
    {
        "messages": chat_history.messages,
        "context": docs,
    }
)

# 4. 생성된 답변을 메모리에 저장합니다.
chat_history.add_ai_message(answer) 

print(answer)
# Out:
# 홍수에 대한 걱정은 이해할 수 있습니다. 농업용 저수지의 효과적인 홍수기 관리는 중요한 문제로 다루어지고 있습니다. 특히, 홍수시에 저수지 및 하류지역이 피해를 입지 않도록 수위를 적절히 관리하는 것이 필수적입니다. 최근에는 AI 기반 모델을 활용한 홍수 예측과 홍수피해 예경보 기법이 개발되고 있으며, 이는 홍수 발생 전 수위를 예측하고 피해를 최소화할 수 있도록 합니다.
#
# 정부는 이러한 기술을 활용하여 지방하천 위주의 홍수 특보 지점을 확대하고 있으며, 향후 223곳에 이르는 지점에서 인공지능 기반 홍수 예보를 시행할 계획에 있습니다. 이 기법은 홍수위 예측 및 홍수피해 위험 정보를 제공하여 재난 분야 담당자들이 보다 효과적으로 대응할 수 있도록 돕고 있습니다 (Source: Rural Resources, Vol. 66 No. 3, August 2024, p.63).
#
# 홍수에 대한 예방과 대비를 위해 기술 개발과 더불어 관계 기관의 긴밀한 협력과 대중에게 정확한 정보 제공이 중요합니다. AI 기술의 발전은 이러한 체계의 효율성을 높이는 데 기여할 수 있습니다.
